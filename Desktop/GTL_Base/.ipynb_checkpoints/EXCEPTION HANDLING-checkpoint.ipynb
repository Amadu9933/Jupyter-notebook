# %% [markdown]
# ![GTL%20Black.png](attachment:GTL%20Black.png)

# %% [markdown]
# ## Error
# * Errors are the mistakes or faults in the program that causes our program to behave unexpectly.
#
# * if not handeled properly will lead to failure and program crashes.
#
# * when actual output of your program is not equal to expected output your program is said to have an error.

# %% [markdown]
# ## Syntax Error or Parsing Error
# * Error caused by not following the proper structure (syntax) of the language are called as syntax error or parsing error

# %%
for i in range(5)
    print(i)
# Out:
#   Input In [3]
#     for i in range(5)
#                      ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Exception
# Errors can also occur at runtime and these are called exceptions.
#
# Exceptions may occur due to
#
# * improper user input.
# * Resoures not present. (e.g. file not present)
# If exception occur and they are not handled properly execution gets terminated.
#
# Whenever these type of runtime error occur, Python creates an exception object. If not handled properly, it prints a traceback to that error along with some details about why that error occurred.

# %% [markdown]
# ## FileNotFoundError

# %%
with open("exception.txt","w") as sadock:
    sadock.write("this is an example \n stilll going")
    sadock.close()

with open("exception.txt","r") as f:
    for letter in f:
        print(letter)
# Out:
# this is an example
#
#  stilll going

# %% [markdown]
# ## ZeroDivisionError

# %%
10 * (1/0)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Input In [5], in <cell line: 1>()
# ----> 1 10 * (1/0)
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ## NameError

# %%
4 + spam*3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 4 + spam*3
#
# NameError: name 'spam' is not defined

# %% [markdown]
# ## TypeError

# %%
'2' + 2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 1>()
# ----> 1 '2' + 2
#
# TypeError: can only concatenate str (not "int") to str

# %% [markdown]
# ## Exception Handling
# Using try-except block

# %%
try:
    -----
    -----
except:
    -----
    -----

# %%
try :
    num1 = int (input(" enter any number "))
    num2 = int (input("enter any number "))
    res = num1/num2
    print(res)

except :
    print("Exception Caught")
# Out:
#  enter any number y
# Exception Caught

# %% [markdown]
# * The try block contains code that might throw an exception.
# * If that exception occurs, the code in the try block stops being executed, and the code in the except block is executed.
# * If no error occurs, the code in the except block doesn't execute.

# %% [markdown]
# ## Catching exceptions
# using single except block

# %%
import sys

try :
    num1 = int (input(" enter any number "))
    num2 = int (input("enter any number "))
    res = num1/num2
    print(res)

except :
    print(sys.exc_info()[0])
# Out:
#  enter any number q
# <class 'ValueError'>

# %% [markdown]
# ## Handling Multiple Exceptions With A Single Except

# %%
try:

#your code goes here
except(Exception1[, Exception2[,...ExceptionN]]]):

#handle exception here

# %%
try :
    num1 = int (input(" enter any number "))
    num2 = int (input("enter any number "))
    res = num5/num2
    print(res)

except (ZeroDivisionError,ValueError) as e:
    print(e)
# Out:
#  enter any number 1
# enter any number 9
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [27], in <cell line: 1>()
#       2     num1 = int (input(" enter any number "))
#       3     num2 = int (input("enter any number "))
# ----> 4     res = num5/num2
#       5     print(res)
#       7 except (ZeroDivisionError,ValueError) as e:
#
# NameError: name 'num5' is not defined

# %% [markdown]
# ## Handling Multiple Exceptions With Multiple Excepts blocks

# %%
try:

#your code goes here

except Exception1:

#handle exception1 here

except Exception2:

    #handle exception2 here

except ExceptionN:

    #handle exceptionN here

# %%
try :
    num1 = int (input(" enter any number "))
    num2 = int (input("enter any number "))
    res = num1*num2
    print(res)

except ZeroDivisionError as e:
    print(e)
    
except TypeError as e:
    print(e)
    
except:
    print("Caught unknown Exception")
# Out:
#  enter any number 1
# enter any number w
# Caught unknown Exception

# %% [markdown]
# ## example of exception handling while working with files

# %%
filename = input("Enter the file name")

try:
    with open(filename) as f_obj:
        content = f_obj.read()
        print(content)

except (FileNotFoundError,PermissionError) as e:
    print(f" Error while opening the file : {e}")
# Out:
# Enter the file namejane
#  Error while opening the file : [Errno 2] No such file or directory: 'jane'

# %% [markdown]
# ## try-except-else block
# * try block - it contains code which might throw exception.
#
# * except block - it contains error handling code which is to be executed if exceptions are not raised.
#
# * else block- it is a option bolck , it will run if exception is not raised in try block, allows to add aitional code if exceptions is not raised.

# %%
filename = input("Enter the file name")

try:
    f_obj = open(filename) 
    content = f_obj.read()

except FileNotFoundError:
    msg = "Sorry, the file " + filename + " does not exist."
    print(msg)
    
else: 
    print(content)
    f_obj.close()

# %% [markdown]
# ## finally block

# %%
def divide(x, y):
    try:
        result = x / y
    
    except ZeroDivisionError:
        print("division by zero!")
    
    else:
        print("result is", result)

    finally:
        print("executing finally clause")

# %%
# if try bolck dosent thorw any exception
divide(2, 1)
# Out:
# result is 2.0
# executing finally clause

# %%
# if try block throws any exception
divide(2, 0)
# Out:
# division by zero!
# executing finally clause

# %%
divide("2", "1")
# Out:
# executing finally clause
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [37], in <cell line: 1>()
# ----> 1 divide("2", "1")
#
# Input In [34], in divide(x, y)
#       1 def divide(x, y):
#       2     try:
# ----> 3         result = x / y
#       5     except ZeroDivisionError:
#       6         print("division by zero!")
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %% [markdown]
# * If a finally clause includes a return statement, the returned value will be the one from the finally clause’s return statement, not the value from the try clause’s return statement.

# %%
# finally block will be exceted just before break continue and return statement

def bool_return():
    try:
        return True
    finally:
        return False

# %%
bool_return()

# %% [markdown]
# * The try statement has another optional clause which is intended to define clean-up actions that must be executed under all circumstances. -Releaseing the resources. The code under finally block executes in all circumstances.
#
# * If a finally clause is present, the finally clause will execute as the last task before the try statement completes.
#
# * The finally block will be executed no matter if the try block raises an error or not.
#
# * If the try statement reaches a break, continue or return statement, the finally clause will execute just prior to the break, continue or return statement’s execution.

# %%
r= "introduction to python"
r[3:12:3]
# Out:
# 'rui'
