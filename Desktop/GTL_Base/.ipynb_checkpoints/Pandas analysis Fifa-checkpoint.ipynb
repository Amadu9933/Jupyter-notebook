# %% [markdown]
# PIP Install and version

# %%
#pip install pandas

import pandas as pd

print(pd.__version__)

#1.3.5
#Latest version: 1.4.1
# Out:
# 1.4.2

# %% [markdown]
# Create a PAndas series from a list-Normal index and custom index

# %%
# Create a pandas data series from a list:

L1 = ['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian']

pseries_1 = pd.Series(data = L1)
pseries_1

# %%
#create a pandas data series with index
car_index = ['car1','car2','car3','ev1','ev2','ev3']

pseries_2 = pd.Series(data = L1,index = car_index)
pseries_2

# %% [markdown]
# Create a pandas series from a python dictionary:

# %%
#Create a pandas series from a python dictionary.
pdict_1 = {
    'car1': 'Honda',
    'car2': 'Toyota',
    'car3': 'Ford',
    'car4': 'GM',
    'car5': 'BMW',
    'car6': 'Nissan',
'car7':'kantanka'}
pdict_1

# %%
pseries_2 = pd.Series(pdict_1)
pseries_2

# %% [markdown]
# Create a pandas series from a numpy array

# %%
#Create a pandas series from a Numpy array
import numpy as np
array_01 = np.random.randn(5)
array_01

# %%
pseries_3 = pd.Series(array_01)
pseries_3

# %% [markdown]
# Create a pandas series from a scalar value

# %%
#If data is a scalar value, an index must be provided. 
#The value will be repeated to match the length of index.
pseries_4 = pd.Series(8.0, index=["a", "b", "c", "d", "e"])
pseries_4

# %% [markdown]
# Pandas series has a dtype

# %%
#Like a NumPy array, a pandas Series has a dtype.
pseries_3.dtypes

# %%
pseries_2.dtypes

# %% [markdown]
# Seires-Attributes-Sort_index,sort_value,describe,shape:

# %%
#Shape,index,values,len,describe:
pseries_2.shape

# %%
pseries_2.describe

# %%
pseries_2.index

# %%
pseries_2.values

# %%
pseries_2.sort_index

# %%
pseries_2.sort_values(inplace=True)
pseries_2

# %% [markdown]
# 9.Pandas series-name,rename,and is unique attributes

# %%
#Series can also have a name attribute:
pseries_5 = pd.Series(pdict_1, name='cars')
pseries_5.name

# %%
#You can rename a Series with the pandas.Series.rename() method.
pseries_6= pseries_5.rename("different_cars")
pseries_6.name

# %%
# Check if all elements are unique 
pseries_6.is_unique

# %% [markdown]
# 10. Pandas series-some methods-describe,head,tail,isnull

# %%
#Here are few methods. There are around 50-60 mothods. Check the documentation
pseries_4.describe()

# %%
pseries_4.head(2)

# %%
pseries_4.isnull()

# %%
pseries_4.sum()

# %%
pseries_4.product()

# %% [markdown]
# 11. finding missing values in Pandas series

# %%
ps6 = pd.Series([10,np.nan,20,30,np.nan])
ps6.isna()

# %%
ps6.isna().sum()

# %% [markdown]
# 12.Using python built-in functions with pandas series

# %%
# Python buildin functions:
ps7 = pd.Series(np.random.randn(10))
ps7

# %%
len(ps7)

# %%
max(ps7)

# %%
min(ps7)

# %%
type(ps7)

# %% [markdown]
# 13.convert a pandas series to-list,dictionary, and numpy array

# %%
L1 = ['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian']
ps_8 = pd.Series(data = L1)

# %%
#convert a series to a list
list(ps_8)

# %%
#convert a series to dictionary
dict(ps_8)

# %%
#convert a series to a narray
na1 = ps_8.values
na1

# %%
type(na1)

# %% [markdown]
# 14.selecting/slicing data from pandas series:

# %%
#Selecting data from a pandas series
L1 = ['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian']
ps_8 = pd.Series(data = L1)

# %%
ps_8[2]

# %%
ps_8[0:2]

# %%
ps_8[-1:]

# %% [markdown]
# 15. pandas series-nlargest and nsmallest

# %%
countries_population = {"Italy": 59000000, "France": 65000000,
                        "Malta": 434000, "Maldives": 434000,
                        "Brunei": 434000, "Iceland": 337000,
                        "Nauru": 11300, "Tuvalu": 11300,
                        "Anguilla": 11300, "Montserrat": 5200}
ps_9 = pd.Series(countries_population)

# %%
#The n largest elements where n=5 by default.
ps_9.nlargest()

# %%
ps_9.nsmallest()

# %% [markdown]
# What is pandas DataFrame?
#
# DataFrame

# %% [markdown]
# Create a Pandas DataFrame

# %%
cars_df = pd.DataFrame({'Cars':['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian'], 
                        'Type':['IC', 'IC', 'IC', 'EV', 'EV', 'EV'],'model':[2012,2020,2011,2008,2022,2006]})
cars_df

# %% [markdown]
# 18. Create a dataframe from a numpy arrays

# %%
#create a dataframe from a numpy array
narray_df = pd.DataFrame(np.random.normal(size=(4,5)))
narray_df

# %% [markdown]
# 19. Df from a pandas series

# %%
#Create a dataframe from single series
s1 = pd.Series([1,2], index=['a','b'])
series_df = pd.DataFrame([s1])
series_df

# %%
     
#Create a dataframe from multiple series and multiple indices
list_of_series = [pd.Series([1,2],index=['a','b']), pd.Series([3,4],index=['a','c'])]
series2_df = pd.concat(list_of_series, axis=1).transpose()
series2_df

# %% [markdown]
# Creaating a DF reading a CSV file

# %%
df = pd.read_csv("fifa_data.csv")

# %% [markdown]
# Available file formats-pd.read:
# ![pandas_read_methods.png](attachment:pandas_read_methods.png)

# %% [markdown]
# PD.read other functions

# %%
#Read from a url
url = "https://www.fdic.gov/resources/resolutions/bank-failures/failed-bank-list"
dfs = pd.read_html(url)

dfs[0]

# %%
#Reading from a excel file
xlsx = pd.ExcelFile('C:/Users/MTL9/Documents/gtl_ds/Sample.Database.xlsx')
df = pd.read_excel(xlsx, "SampleDatabase")
df

# %% [markdown]
# Read from SQL table and Query

# %%
#pd.read_sql_table("data", engine)
#pd.read_sql_query("SELECT * FROM data", engine)
#pd.read_sql_query("SELECT id, Col_1, Col_2 FROM data WHERE id = 42;", engine)

# %% [markdown]
# Write a dataframe to a csv file(with index or without index)
#
# use to_csv

# %%
# write to a csv file with an index
housing_df.to_csv("/content/sample_data/california_housing_test1.csv", index = True)
#default is True

# %%
# write to a csv file without an index
housing_df.to_csv("/content/sample_data/california_housing_test2.csv", index = False)

# %% [markdown]
# Create an index using a column & reset the index to the original index:

# %%
#set your own index
df.set_index(“col_name”, inplace = True)
#reset the index to original index
df.reset_index(inplace = True)
#Set the index when reading the file
housing_df = pd.read_csv("/content/sample_data/california_housing_test.csv", index_col = 'City')

# %%
# What is inplace=True in Pandas:

#For example, take the above example

df.set_index(“col_name”, inplace = True)#No need to assign it to variable

#If inplace=True then no need to assign it to a variable. The default option is False. If you use the default option then you need to assign it to a variable.

df = df.set_index(“col_name”)

# %% [markdown]
# selecting a column and multiple columns from a dataframe

# %%
my_df['col1'] #pass the name of the column the data type of the single column is pandas series

# %%
my_df[['col1','col2']] #pass a list of columns the data type multiple columns is the dataframe.

# %% [markdown]
# Column operations : adding and inserting a column

# %%
# Add a column
cars_df = pd.DataFrame({'Cars':['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian'], 
                        'Type':['IC', 'IC', 'IC', 'EV', 'EV', 'EV']})
cars_df['Price'] = [30000, 35000,25000,50000,120000,90000]
cars_df

# %%
#Insert a column based on the index.Here index 1
cars_df = pd.DataFrame({'Cars':['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian'], 
                        'Type':['IC', 'IC', 'IC', 'EV', 'EV', 'EV']})

cars_df.insert(1,column = 'Price', value = [30000, 35000,25000,50000,120000,90000] )
cars_df

# %%
df.head()

# %%
df.shape

# %%
df.columns

# %%
gt=df[['Name','Nationality','Club','Preferred Foot']]

# %%
a=gt.loc[df['Preferred Foot']=='Left'].count()[3]

# %%
b=gt.loc[df['Preferred Foot']=='Right'].count()[3]

# %%
our_best=df[['Name','Nationality','Club','Overall']]

# %%
our_best.loc[df['Overall']>90]

# %%
cars_df = pd.DataFrame({'Cars':['Honda', 'Toyota','Ford','Tesla','Lucid','Rivian'], 
                        'Type':['IC', 'IC', 'IC', 'EV', 'EV', 'EV'],
                        'Price':[30000, 35000,25000,50000,120000,90000]})
#Delete a column
del cars_df['Price']
cars_df

#Delete a column using drop
cars_df.drop(labels = ["Type"], axis = 1, inplace = True)
cars_df
  
#delete a column using pop and store that column in a another variable.
#prices_df = cars_df.pop('Price')
#prices_df

# %%
#Set the index based on the passenger class
titanic_df = pd.read_csv("/content/sample_data/train.csv", index_col='Pclass')
titanic_df
#select the passengers travel in class 1
titanic_df.loc[1,'Name']

Pclass
1    Cumings, Mrs. John Bradley (Florence Briggs Th...
1         Futrelle, Mrs. Jacques Heath (Lily May Peel)
1                              McCarthy, Mr. Timothy J
1

# %%
import pandas as pd
titanic_df = pd.read_csv("/content/sample_data/train.csv")
titanic_df

#use iloc to filter the dataframe
titanic_df.loc[1:5]

titanic_df.iloc[[10, 24, 90]]

titanic_df.iloc[:9]

titanic_df.iloc[90, 0:5]

# %%
#Column values manipulate.
titanic_df[‘New Fare’] = titanic_df[‘Fare’].add(10)
titanic_df

# %%
titanic_df = pd.read_csv("/content/sample_data/train.csv")
#Use the Titanic dataset from kaggle-sort by values-sort the column Age
titanic_df.sort_values(by = 'Age', inplace = True) 
titanic_df

#Sort by index
titanic_df.sort_index(inplace = True)

# %%
#Calculate the tax of about 20% of the fare.Create a new column called Tax
def tax_cal(fare):
  return fare * 0.2

titanic_df['Tax'] = titanic_df['Fare'].apply(tax_cal)
titanic_df

# %%
import matplotlib.pyplot as plt

# %%
label=['left','right']
plt.pie([a,b],labels=label,autopct='%.2f %%',colors=['m','y'])
plt.legend()
plt.show()
