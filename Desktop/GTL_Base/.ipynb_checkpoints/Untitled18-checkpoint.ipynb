# %%
import pandas as pd

file_name = "https://raw.githubusercontent.com/rajeevratan84/datascienceforbusiness/master/amazon_fires.csv"
df = pd.read_csv(file_name, encoding = "ISO-8859-1")
df
# Out:
#        ano       mes     estado   numero  encontro
# 0     1998   Janeiro       Acre  0 Fires  1/1/1998
# 1     1999   Janeiro       Acre  0 Fires  1/1/1999
# 2     2000   Janeiro       Acre  0 Fires  1/1/2000
# 3     2001   Janeiro       Acre  0 Fires  1/1/2001
# 4     2002   Janeiro       Acre  0 Fires  1/1/2002
# ...    ...       ...        ...      ...       ...
# 6449  2012  Dezembro  Tocantins      128  1/1/2012
# 6450  2013  Dezembro  Tocantins       85  1/1/2013
# 6451  2014  Dezembro  Tocantins      223  1/1/2014
# 6452  2015  Dezembro  Tocantins      373  1/1/2015
# 6453  2016  Dezembro  Tocantins      119  1/1/2016
#
# [6454 rows x 5 columns]

# %%
new_columns = {'ano' : 'year',
               'estado': 'state',
               'mes': 'month',
               'numero': 'number_of_fires',
               'encontro': 'date'}
df.rename(columns = new_columns, inplace=True)
df['state'] = df['state'].str.title()

df['number_of_fires'] = df['number_of_fires'].str.strip(" Fires")
df['number_of_fires'] = df['number_of_fires'].fillna(0)
df['number_of_fires'] = df['number_of_fires'].astype(float)


# Introuding the Map Function
month_translations = {'Janeiro': 'January',
'Fevereiro': 'February',
'Março': 'March',
'Abril': 'April',
'Maio': 'May',
'Junho': 'June',
'Julho': 'July',
'Agosto': 'August',
'Setembro': 'September',
'Outubro': 'October',
'Novembro': 'November',
'Dezembro': 'December'}

df["month"] = df["month"].map(month_translations)
df.head(15)
# Out:
#     year    month state  number_of_fires      date
# 0   1998  January  Acre              0.0  1/1/1998
# 1   1999  January  Acre              0.0  1/1/1999
# 2   2000  January  Acre              0.0  1/1/2000
# 3   2001  January  Acre              0.0  1/1/2001
# 4   2002  January  Acre              0.0  1/1/2002
# 5   2003  January  Acre             10.0  1/1/2003
# 6   2004  January  Acre              0.0  1/1/2004
# 7   2005  January  Acre             12.0  1/1/2005
# 8   2006  January  Acre              4.0  1/1/2006
# 9   2007  January  Acre              0.0  1/1/2007
# 10  2008  January  Acre              0.0  1/1/2008
# 11  2009  January  Acre              0.0  1/1/2009
# 12  2010  January  Acre              1.0  1/1/2010
# 13  2011  January  Acre              0.0  1/1/2011
# 14  2012  January  Acre              0.0  1/1/2012

# %%
# !pip install matplotlib==3.5.0
# Out:
# Collecting matplotlib==3.5.0
#   Using cached matplotlib-3.5.0-cp39-cp39-win_amd64.whl (7.2 MB)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (21.3)
# Requirement already satisfied: numpy>=1.17 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (1.21.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (2.8.2)
# Requirement already satisfied: setuptools-scm>=4 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (7.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (3.0.4)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\dell\anaconda3\lib\site-packages (from matplotlib==3.5.0) (9.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\dell\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib==3.5.0) (1.16.0)
# Requirement already satisfied: typing-extensions in c:\users\dell\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (4.1.1)
# Requirement already satisfied: tomli>=1.0.0 in c:\users\dell\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (1.2.2)
# Requirement already satisfied: setuptools in c:\users\dell\anaconda3\lib\site-packages (from setuptools-scm>=4->matplotlib==3.5.0) (61.2.0)
# Installing collected packages: matplotlib
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)
# ERROR: Could not install packages due to an OSError: [WinError 32] The process cannot access the file because it is being used by another process: 'C:\\Users\\DELL\\anaconda3\\Lib\\site-packages\\matplotlib\\mpl-data\\fonts\\ttf\\DejaVuSans.ttf'
# Consider using the `--user` option or check the permissions.
#
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)
# WARNING: Ignoring invalid distribution -atplotlib (c:\users\dell\anaconda3\lib\site-packages)

# %%
import numpy as np
import matplotlib as plt
import seaborn as sns
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [10], in <cell line: 3>()
#       1 import numpy as np
#       2 import matplotlib as plt
# ----> 3 import seaborn as sns
#       4 get_ipython().run_line_magic('matplotlib', 'inline')
#
# File ~\anaconda3\lib\site-packages\seaborn\__init__.py:2, in <module>
#       1 # Import seaborn objects
# ----> 2 from .rcmod import *  # noqa: F401,F403
#       3 from .utils import *  # noqa: F401,F403
#       4 from .palettes import *  # noqa: F401,F403
#
# File ~\anaconda3\lib\site-packages\seaborn\rcmod.py:7, in <module>
#       5 import matplotlib as mpl
#       6 from cycler import cycler
# ----> 7 from . import palettes
#      10 __all__ = ["set_theme", "set", "reset_defaults", "reset_orig",
#      11            "axes_style", "set_style", "plotting_context", "set_context",
#      12            "set_palette"]
#      15 _style_keys = [
#      16
#      17     "axes.facecolor",
#    (...)
#      52
#      53 ]
#
# File ~\anaconda3\lib\site-packages\seaborn\palettes.py:9, in <module>
#       5 import matplotlib as mpl
#       7 from .external import husl
# ----> 9 from .utils import desaturate, get_color_cycle
#      10 from .colors import xkcd_rgb, crayons
#      13 __all__ = ["color_palette", "hls_palette", "husl_palette", "mpl_palette",
#      14            "dark_palette", "light_palette", "diverging_palette",
#      15            "blend_palette", "xkcd_palette", "crayon_palette",
#      16            "cubehelix_palette", "set_color_codes"]
#
# File ~\anaconda3\lib\site-packages\seaborn\utils.py:14, in <module>
#      12 import matplotlib as mpl
#      13 import matplotlib.colors as mplcol
# ---> 14 import matplotlib.pyplot as plt
#      15 from matplotlib.cbook import normalize_kwargs
#      18 __all__ = ["desaturate", "saturate", "set_hls_values", "move_legend",
#      19            "despine", "get_dataset_names", "get_data_home", "load_dataset"]
#
# File ~\anaconda3\lib\site-packages\matplotlib\pyplot.py:49, in <module>
#      47 from cycler import cycler
#      48 import matplotlib
# ---> 49 import matplotlib.colorbar
#      50 import matplotlib.image
#      51 from matplotlib import _api
#
# File ~\anaconda3\lib\site-packages\matplotlib\colorbar.py:21, in <module>
#      18 import numpy as np
#      20 import matplotlib as mpl
# ---> 21 from matplotlib import _api, collections, cm, colors, contour, ticker
#      22 import matplotlib.artist as martist
#      23 import matplotlib.patches as mpatches
#
# File ~\anaconda3\lib\site-packages\matplotlib\collections.py:20, in <module>
#      17 import numpy as np
#      19 import matplotlib as mpl
# ---> 20 from . import (_api, _path, artist, cbook, cm, colors as mcolors, docstring,
#      21                hatch as mhatch, lines as mlines, path as mpath, transforms)
#      22 from ._enums import JoinStyle, CapStyle
#      25 # "color" is excluded; it is a compound setter, and its docstring differs
#      26 # in LineCollection.
#
# File ~\anaconda3\lib\site-packages\matplotlib\artist.py:15, in <module>
#      13 import matplotlib as mpl
#      14 from . import _api, cbook
# ---> 15 from .cm import ScalarMappable
#      16 from .path import Path
#      17 from .transforms import (Bbox, IdentityTransform, Transform, TransformedBbox,
#      18                          TransformedPatchPath, TransformedPath)
#
# File ~\anaconda3\lib\site-packages\matplotlib\cm.py:36, in <module>
#      29 @_api.caching_module_getattr  # module-level deprecations
#      30 class __getattr__:
#      31     LUTSIZE = _api.deprecated(
#      32         "3.5", obj_type="", alternative="rcParams['image.lut']")(
#      33             property(lambda self: _LUTSIZE))
# ---> 36 _LUTSIZE = mpl.rcParams['image.lut']
#      39 def _gen_cmap_registry():
#      40     """
#      41     Generate a dict mapping standard colormap names to standard colormaps, as
#      42     well as the reversed colormaps.
#      43     """
#
# AttributeError: module 'matplotlib' has no attribute 'rcParams'
