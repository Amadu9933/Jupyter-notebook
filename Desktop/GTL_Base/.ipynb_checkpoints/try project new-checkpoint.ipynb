# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import plotly.express as px
# %matplotlib inline

# %%
#Reading the csv file from the disk 
df=pd.read_csv('bank_marketing.csv')
df.head()
# Out:
#    Unnamed: 0  age        job  marital    education  default housing loan  \
# 0           0   56  housemaid  married     basic.4y       no      no   no
# 1           1   57   services  married  high.school  unknown      no   no
# 2           2   37   services  married  high.school       no     yes   no
# 3           3   40     admin.  married     basic.6y       no      no   no
# 4           4   45   services  married     basic.9y  unknown      no   no
#
#      contact month  ... campaign  pdays  previous     poutcome  emp.var.rate  \
# 0  telephone   may  ...        1    999         0  nonexistent           1.1
# 1  telephone   may  ...        1    999         0  nonexistent           1.1
# 2  telephone   may  ...        1    999         0  nonexistent           1.1
# 3  telephone   may  ...        1    999         0  nonexistent           1.1
# 4  telephone   may  ...        1    999         0  nonexistent           1.1
#
# ...

# %%
#checking the stats on the various numerical columns
#from the result the min and max age are 17 and 98 respectively
# the maximum number of employees is 5228
df.describe()
# Out:
#          Unnamed: 0           age      duration      campaign         pdays  \
# count  32951.000000  32951.000000  32951.000000  32951.000000  32951.000000
# mean   16475.000000     40.000941    258.854299      2.558314    962.537131
# std     9512.278697     10.410233    259.167585      2.732370    186.757655
# min        0.000000     17.000000      0.000000      1.000000      0.000000
# 25%     8237.500000     32.000000    103.000000      1.000000    999.000000
# 50%    16475.000000     38.000000    180.000000      2.000000    999.000000
# 75%    24712.500000     47.000000    320.000000      3.000000    999.000000
# max    32950.000000     98.000000   4199.000000     56.000000    999.000000
#
#            previous  emp.var.rate  cons.price.idx  cons.conf.idx  \
# count  32951.000000  32951.000000    32951.000000   32951.000000
# mean       0.172620      0.084820       93.575129     -40.491921
# std        0.493482      1.570037        0.578020       4.629348
# ...

# %%
df.shape
# Out:
# (32951, 22)

# %%
df.describe(include='object')
# Out:
#            job  marital          education default housing   loan   contact  \
# count    32951    32951              32951   32951   32951  32951     32951
# unique      12        4                  8       3       3      3         2
# top     admin.  married  university.degree      no     yes     no  cellular
# freq      8307    19887               9691   26108   17314  27128     20929
#
#         month day_of_week     poutcome      y
# count   32951       32951        32951  32951
# unique     10           5            3      2
# top       may         thu  nonexistent     no
# freq    11018        6882        28450  29239

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'age', 'job', 'marital', 'education', 'default',
#        'housing', 'loan', 'contact', 'month', 'day_of_week', 'duration',
#        'campaign', 'pdays', 'previous', 'poutcome', 'emp.var.rate',
#        'cons.price.idx', 'cons.conf.idx', 'euribor3m', 'nr.employed', 'y'],
#       dtype='object')

# %%
plt.figure(figsize=(7,8))
colors=['#7FF0F4','#F4FFEF','b','y','r']
plt.pie(status, labels=['married','single','divorced','unknown'], 
        autopct='% .2f %%', explode=[0.1,0,0.1,0.1], 
        colors=['#7FF0F4','#F4dFEF','y','r','green'])
plt.title('The Percentage of the Marital Statuses of Clients')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8,2))
sns.set_theme(style="darkgrid")
sns.countplot(data=df,x='marital',hue='y',palette='tab10')
plt.title('')
plt.show()


print(df['marital'].value_counts())
# Out:
# married     19887
# single       9319
# divorced     3681
# unknown        64
# Name: marital, dtype: int64

# %%
#distribution of clients age 

fig=px.histogram(df,x='age',
                 marginal='box',
                 color_discrete_sequence=['green'],
                 title='client distribution of age')
fig.update_layout(bargap=0.1)
fig.show()
# Out:
# <div>                            <div id="367a2dff-aeab-4103-9202-d27f819214f2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("367a2dff-aeab-4103-9202-d27f819214f2")) {                    Plotly.newPlot(                        "367a2dff-aeab-4103-9202-d27f819214f2",                        [{"alignmentgroup":"True","bingroup":"x","hovertemplate":"age=%{x}<br>count=%{y}<extra></extra>","legendgroup":"","marker":{"color":"green","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"x":[56,57,37,40,45,59,24,25,41,29,57,35,54,50,39,30,55,55,41,37,35,59,39,54,55,46,59,49,54,54,34,52,41,58,32,38,57,44,42,57,35,54,39,60,55,50,45,55,47,51,42,42,48,37,44,33,56,44,41,44,47,57,37,41,55,33,55,50,49,38,31,41,39,49,34,35,57,42,4
# ...

# %%
#sns.set_theme(style="darkgrid")
facecolor=(4, 0, 2, 2)
sns.countplot(data=df,x='y')
plt.title('Number of clients that subscribed and not')
plt.show()

countno=len(df[df.y=='no'])
countyes=len(df[df.y=='yes'])

print('Percentage of clients who did not subscribe: {:.2f}%'.format((countno/(len(df.y))*100)))

print('Percentage of clients who subscribe: {:.2f}%'.format((countyes/(len(df.y))*100)))
# Out:
# Percentage of clients who did not subscribe: 88.73%
# Percentage of clients who subscribe: 11.27%

# %%
pd.crosstab(df['education'],
           df['job'],
           normalize='index')
print('')
# Out:
# job                    admin.  blue-collar  entrepreneur  housemaid  \
# education
# basic.4y             0.018160     0.556118      0.033046   0.116106
# basic.6y             0.059271     0.626971      0.032083   0.032083
# basic.9y             0.081590     0.595361      0.034997   0.014910
# high.school          0.351270     0.091041      0.025260   0.018813
# illiterate           0.062500     0.437500      0.062500   0.062500
# professional.course  0.065274     0.085687      0.023736   0.010681
# university.degree    0.473945     0.007636      0.051078   0.010216
# unknown              0.145403     0.255167      0.032074   0.020670
#
# job                  management   retired  self-employed  services   student  \
# education
# basic.4y               0.022923  0.142007       0.021435  0.032450  0.006550
# basic.6y               0.035345  0.036977       0.011419  0.101142  0.005438
# basic.9y               0.027542  0.025471       0.037275  0.063160  0.018223
# ...

# %%
plt.figure(figsize=(15,5))
#sns.set_theme(style="darkgrid")

sns.countplot(data=df,x='job',hue='y',palette='tab10')
plt.title('subscription by job type')
plt.show()

print('percentage of subscription')
print(df['job'].value_counts(normalize='index'))
# Out:
# percentage of subscription
# admin.           0.252102
# blue-collar      0.224212
# technician       0.163758
# services         0.097266
# management       0.069527
# retired          0.042336
# entrepreneur     0.035568
# self-employed    0.035386
# housemaid        0.025432
# unemployed       0.024764
# student          0.021456
# unknown          0.008194
# Name: job, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='education',hue='y',palette='pastel')
plt.title('Subscription by Education')
plt.show()
print(df['education'].value_counts(normalize='index'))
# Out:
# university.degree      0.294103
# high.school            0.230676
# basic.9y               0.146551
# professional.course    0.127857
# basic.4y               0.101939
# basic.6y               0.055810
# unknown                0.042578
# illiterate             0.000486
# Name: education, dtype: float64

# %%
plt.figure(figsize=(15,5))
sns.countplot(data=df,x='loan',hue='y',palette='Paired')
plt.title('subscription by loan Status')
plt.show()

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
##From the output below we can see the heighest score is 19 for the nodes. 

scorelistDT=[]
for i in range(2,20):
    DTclassifier=DecisionTreeClassifier(max_leaf_nodes=i,)
    DTclassifier.fit(x_train, z_train)
    scorelistDT.append(DTclassifier.score(x_test, z_test))
    
plt.plot(range(2,20), scorelistDT)
plt.xticks(np.arange(2,20,1))
plt.xlabel('leaf')
plt.ylabel('score')
plt.show()
DTaccuracy=max(scorelistDT)
print('Decision Tree accuracy: {:.2f}%'.format(DTaccuracy*100))

# %%
DTmodel = DecisionTreeClassifier(max_leaf_nodes=16,random_state=42)

# %%
DTmodel.fit(x_train, z_train)

# %%
print('Score of train is :',DTmodel.score(x_train,z_train))
print('Score of test is :',DTmodel.score(x_test,z_test))

# %%
DT_predict=DTmodel.predict(x_train)
DT_predict

# %%
accuracy_score(z_train,DT_predict)

# %%
DT_predictt=DTmodel.predict(x_test)
DT_predictt

# %%
accuracy_score(z_test,DT_predictt)

# %%
# Import necessary modules
from sklearn.neighbors import KNeighborsClassifier

# %%
knn_predict_train=KNN.predict(x_train)

# %%
knn_acc_train=accuracy_score(z_train, knn_predict_train)
knn_acc_train

# %%
print('Score of train is :',KNN.score(x_train,z_train))
print('Score of test is :',KNN.score(x_test,z_test))

# %%
knn_predict=KNN.predict(x_test)

# %%
knn_acc=accuracy_score(z_test, knn_predict)
knn_acc

# %%
error = []

# Calculating error for K values between 1 and 40,The above script executes a loop from 1 to 40. 
# In each iteration the mean error for predicted values of test set is calculated and the result is appended to the error list.
for i in range(1, 70):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, z_train)
    pred_i = knn.predict(x_test)
    error.append(np.mean(pred_i != z_test))

# %%
#ploting the error values against K values
plt.figure(figsize=(12, 6))
plt.plot(range(1, 70), error, color='red', linestyle='dashed', marker='o',
         markerfacecolor='blue', markersize=10)
plt.title('Error Rate K Value')
plt.xlabel('K Value')
plt.ylabel('Mean Error')

#From the output below we can see that the mean error  which is smaler when the value of the K is between 50 and 55.

# %%
from sklearn.svm import SVC
SVCclassifier=SVC(C=4, kernel='rbf',degree=2, max_iter=1000)  
SVCclassifier.fit(x_train,z_train)
print('Score of train is :',SVCclassifier.score(x_train,z_train))
print('Score of test is :',SVCclassifier.score(x_test,z_test))

# %%
z_predict=SVCclassifier.predict (x_test)
z_predict

# %%
print('Score of train is :',SVCclassifier.score(x_train,z_train))
print('Score of test is :',SVCclassifier.score(x_test,z_test))

# %%
conf=confusion_matrix(z_test,z_predict)
conf

# %%
from sklearn.tree import DecisionTreeClassifier

model = DecisionTreeClassifier(random_state=42)
# %%time
model.fit(X_train, train_targets)

#Evaluation
from sklearn.metrics import accuracy_score, confusion_matrix
train_preds = model.predict(X_train)
train_preds

# %%
model.fit(X_train, train_targets)

# %%
train_preds

# %%
train_probs = model.predict_proba(X_train)
train_probs

# %%
#Let's check the accuracy of its predictions.
accuracy_score(train_targets, train_preds)

# %%
model.score(X_val, val_targets)

# %%
model.score(X_train, train_targets)

# %%
model.score(X_test, test_targets,)

# %%
# Import necessary modules
from sklearn.neighbors import KNeighborsClassifier

# %%
KNN=KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
                     metric_params=None, n_jobs=None, n_neighbors=5, p=2,
                     weights='uniform')

# %%
KNN.fit(x_train,z_train)

# %%
knn_predict_train=KNN.predict(x_train)

# %%
knn_acc_train=accuracy_score(z_train, knn_predict_train)
knn_acc_train)

# %%
print('Score of train is :',KNN.score(x_train,z_train))
print('Score of test is :',KNN.score(x_test,z_test))

# %%
knn_predict=KNN.predict(x_test)

# %%
knn_acc=accuracy_score(z_test, knn_predict)
knn_acc

# %%
error = []

# Calculating error for K values between 1 and 40,The above script executes a loop from 1 to 40. 
# In each iteration the mean error for predicted values of test set is calculated and the result is appended to the error list.
for i in range(1, 70):
    knn = KNeighborsClassifier(n_neighbors=i)
    knn.fit(x_train, z_train)
    pred_i = knn.predict(x_test)
    error.append(np.mean(pred_i != z_test))
